# %%
import pandas as pd
import powerplantmatching as pm
import unidecode

# %%
print(pm.__version__)

_orig_unidecode = unidecode.unidecode

def safe_unidecode(x):
    if pd.isna(x):
        return ""
    return _orig_unidecode(str(x))

unidecode.unidecode = safe_unidecode

geo = pm.data.GEO()
# Out:
# 0.8.0
# /home/tom/miniconda3/envs/IES/lib/python3.13/site-packages/powerplantmatching/cleaning.py:255: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   return df.assign(**cols)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[25], line 12
#       8     return _orig_unidecode(str(x))
#      10 unidecode.unidecode = safe_unidecode
# ---> 12 geo = pm.data.GEO()
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/powerplantmatching/data.py:311, in GEO(raw, update, config)
#     303 cols = [
#     304     "Name",
#     305     "Fueltype",
#    (...)    308     "FuelClassification2",
#     309 ]
#     310 ppl = gather_specifications(ppl, parse_columns=cols)
# --> 311 ppl = clean_name(ppl)
#     313 res = units.join(ppl.set_index("projectID"), "projectID", rsuffix="_ppl")
#     314 res["DateIn"] = res.DateIn.fillna(res.DateIn_ppl)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/powerplantmatching/cleaning.py:77, in clean_name(df, config)
#      74 if config is None:
#      75     config = get_config()
# ---> 77 name = df.Name.astype(str).copy().apply(unidecode.unidecode)
#      79 roman_to_arabic = {
#      80     "I": "1",
#      81     "II": "2",
#    (...)     90     "XI": "11",
#      91 }
#      92 for roman, arabic in roman_to_arabic.items():
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/arrays/base.py:2744, in ExtensionArray.map(self, mapper, na_action)
#    2724 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2725     """
#    2726     Map values using an input mapping or function.
#    2727
#    (...)   2742         a MultiIndex will be returned.
#    2743     """
# -> 2744     return map_array(self, mapper, na_action=na_action)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
#     [... skipping similar frames: safe_unidecode at line 8 (2965 times)]
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
# Cell In[25], line 6, in safe_unidecode(x)
#       5 def safe_unidecode(x):
# ----> 6     if pd.isna(x):
#       7         return ""
#       8     return _orig_unidecode(str(x))
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/dtypes/missing.py:174, in isna(obj)
#      97 @set_module("pandas")
#      98 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#      99     """
#     100     Detect missing values for an array-like object.
#     101
#    (...)    172     Name: 1, dtype: bool
#     173     """
# --> 174     return _isna(obj)
#
# RecursionError: maximum recursion depth exceeded

# %%
nl = geo[geo["Country"] == "Netherlands"]
nl.head()

# %%
nl.powerplant.plot_map(figsize=(11, 8));

# %%
nl.powerplant.lookup().head(20).to_frame()
# Out:
#                           Capacity
# Country     Fueltype
# Netherlands Hard Coal     6955.092
#             Natural Gas  14040.822
#             Nuclear        458.027
#             Oil            324.217
#             Waste          238.383
#             Wind             0.000

# %%
nl.powerplant.fill_missing_commissioning_years().head()
# Out:
# GEO                              Name   Fueltype Technology  Set      Country  \
# 454     Gelderland Coal Netherlands 1  Hard Coal        NaN   PP  Netherlands
# 455  Eemshaven Usc Coal Netherlands 1  Hard Coal        NaN   PP  Netherlands
# 456  Eemshaven Usc Coal Netherlands 2  Hard Coal        NaN   PP  Netherlands
# 457       Amer Chp Coal Netherlands 1  Hard Coal       CCGT  CHP  Netherlands
# 458       Amer Chp Coal Netherlands 2  Hard Coal       CCGT  CHP  Netherlands
#
# GEO    Capacity  Efficiency  DateIn  DateRetrofit  DateOut      lat     lon  \
# 454  543.942804         NaN  1981.0        1985.0      NaN  51.8561  5.8294
# 455  737.549565         NaN  2014.0        2014.0      NaN  53.4441  6.8560
# 456  737.549565         NaN  2014.0        2014.0      NaN  53.4441  6.8560
# 457  594.649337         NaN  1980.0        1980.0      NaN  51.7081  4.8438
# 458  553.162174         NaN  1993.0        1993.0      NaN  51.7081  4.8438
#
# GEO  Duration  Volume_Mm3  DamHeight_m  StorageCapacity_MWh  EIC  projectID
# 454       NaN         NaN          NaN                  NaN  NaN  GEO-44518
# 455       NaN         NaN          NaN                  NaN  NaN  GEO-44523
# 456       NaN         NaN          NaN                  NaN  NaN  GEO-44523
# 457       NaN         NaN          NaN                  NaN  NaN  GEO-44517
# 458       NaN         NaN          NaN                  NaN  NaN  GEO-44517

# %%
stats = pm.data.Capacity_stats()

# %%
entsoe = pm.data.ENTSOE()

entsoe.head()

pm.plot.fueltype_totals_bar([geo, entsoe, stats], keys=["ENTSOE", "GEO", "Statistics"]);
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 entsoe = pm.data.ENTSOE()
#       3 entsoe.head()
#       5 pm.plot.fueltype_totals_bar([geo, entsoe, stats], keys=["ENTSOE", "GEO", "Statistics"]);
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/powerplantmatching/data.py:794, in ENTSOE(raw, update, config, entsoe_token, entsoe_session, **fill_geoposition_kwargs)
#     772 fn = _package_data("entsoe_country_codes.csv")
#     773 COUNTRY_MAP = pd.read_csv(fn, index_col=0).rename(index=str).Country
#     775 return (
#     776     df.rename_axis(index="projectID")
#     777     .reset_index()
#     778     .rename(columns=RENAME_COLUMNS)
#     779     .drop_duplicates("projectID")
#     780     .assign(
#     781         Name=lambda df: df.Name.str.replace("_", " "),  # for geoparsing
#     782         EIC=lambda df: df.projectID,
#     783         Country=lambda df: df.projectID.str[:2].map(COUNTRY_MAP),
#     784         Capacity=lambda df: pd.to_numeric(df.Capacity),
#     785         Technology=np.nan,
#     786         Set=np.nan,
#     787         lat=np.nan,
#     788         lon=np.nan,
#     789     )
#     790     .powerplant.convert_alpha2_to_country()
#     791     # .pipe(fill_geoposition, **fill_geoposition_kwargs)
#     792     .query("Capacity > 0")
#     793     .pipe(gather_specifications, config=config)
# --> 794     .pipe(clean_name)
#     795     .pipe(set_column_name, "ENTSOE")
#     796     .pipe(config_filter, config)
#     797 )
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/generic.py:6126, in NDFrame.pipe(self, func, *args, **kwargs)
#    6024 @final
#    6025 def pipe(
#    6026     self,
#    (...)   6029     **kwargs: Any,
#    6030 ) -> T:
#    6031     r"""
#    6032     Apply chainable functions that expect Series or DataFrames.
#    6033
#    (...)   6124     2  3682.80  1473.12
#    6125     """
# -> 6126     return common.pipe(self.copy(deep=False), func, *args, **kwargs)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/common.py:532, in pipe(obj, func, *args, **kwargs)
#     530     return func_(*args, **kwargs)
#     531 else:
# --> 532     return func(obj, *args, **kwargs)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/powerplantmatching/cleaning.py:77, in clean_name(df, config)
#      74 if config is None:
#      75     config = get_config()
# ---> 77 name = df.Name.astype(str).copy().apply(unidecode.unidecode)
#      79 roman_to_arabic = {
#      80     "I": "1",
#      81     "II": "2",
#    (...)     90     "XI": "11",
#      91 }
#      92 for roman, arabic in roman_to_arabic.items():
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/arrays/base.py:2744, in ExtensionArray.map(self, mapper, na_action)
#    2724 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2725     """
#    2726     Map values using an input mapping or function.
#    2727
#    (...)   2742         a MultiIndex will be returned.
#    2743     """
# -> 2744     return map_array(self, mapper, na_action=na_action)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
#     [... skipping similar frames: safe_unidecode at line 8 (2963 times)]
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
# Cell In[25], line 6, in safe_unidecode(x)
#       5 def safe_unidecode(x):
# ----> 6     if pd.isna(x):
#       7         return ""
#       8     return _orig_unidecode(str(x))
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/dtypes/missing.py:174, in isna(obj)
#      97 @set_module("pandas")
#      98 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#      99     """
#     100     Detect missing values for an array-like object.
#     101
#    (...)    172     Name: 1, dtype: bool
#     173     """
# --> 174     return _isna(obj)
#
# RecursionError: maximum recursion depth exceeded

# %%
dfs = [nl.powerplant.aggregate_units(), entsoe.powerplant.aggregate_units()]
intersection = pm.matching.combine_multiple_datasets(dfs)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dfs = [nl.powerplant.aggregate_units(), entsoe.powerplant.aggregate_units()]
#       2 intersection = pm.matching.combine_multiple_datasets(dfs)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/powerplantmatching/cleaning.py:525, in aggregate_units(df, dataset_name, pre_clean_name, country_wise, config, threads, **kwargs)
#     517 with pd.option_context("future.no_silent_downcasting", True):
#     518     df[str_cols] = df[str_cols].replace("", pd.NA).infer_objects(copy=False)
#     520 df = (
#     521     df.assign(
#     522         **df[weighted_cols].div(df["Capacity"], axis=0).where(lambda df: df != 0)
#     523     )
#     524     .reset_index(drop=True)
# --> 525     .pipe(clean_name)
#     526     .reindex(columns=cols)
#     527     .pipe(set_column_name, ds_name)
#     528 )
#     530 # Remove zero values from summed non-weighted numeric columns
#     531 numeric_cols = df.select_dtypes(include="number").columns
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/generic.py:6126, in NDFrame.pipe(self, func, *args, **kwargs)
#    6024 @final
#    6025 def pipe(
#    6026     self,
#    (...)   6029     **kwargs: Any,
#    6030 ) -> T:
#    6031     r"""
#    6032     Apply chainable functions that expect Series or DataFrames.
#    6033
#    (...)   6124     2  3682.80  1473.12
#    6125     """
# -> 6126     return common.pipe(self.copy(deep=False), func, *args, **kwargs)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/common.py:532, in pipe(obj, func, *args, **kwargs)
#     530     return func_(*args, **kwargs)
#     531 else:
# --> 532     return func(obj, *args, **kwargs)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/powerplantmatching/cleaning.py:77, in clean_name(df, config)
#      74 if config is None:
#      75     config = get_config()
# ---> 77 name = df.Name.astype(str).copy().apply(unidecode.unidecode)
#      79 roman_to_arabic = {
#      80     "I": "1",
#      81     "II": "2",
#    (...)     90     "XI": "11",
#      91 }
#      92 for roman, arabic in roman_to_arabic.items():
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/arrays/base.py:2744, in ExtensionArray.map(self, mapper, na_action)
#    2724 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2725     """
#    2726     Map values using an input mapping or function.
#    2727
#    (...)   2742         a MultiIndex will be returned.
#    2743     """
# -> 2744     return map_array(self, mapper, na_action=na_action)
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
#     [... skipping similar frames: safe_unidecode at line 8 (2963 times)]
#
# Cell In[25], line 8, in safe_unidecode(x)
#       6 if pd.isna(x):
#       7     return ""
# ----> 8 return _orig_unidecode(str(x))
#
# Cell In[25], line 6, in safe_unidecode(x)
#       5 def safe_unidecode(x):
# ----> 6     if pd.isna(x):
#       7         return ""
#       8     return _orig_unidecode(str(x))
#
# File ~/miniconda3/envs/IES/lib/python3.13/site-packages/pandas/core/dtypes/missing.py:174, in isna(obj)
#      97 @set_module("pandas")
#      98 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#      99     """
#     100     Detect missing values for an array-like object.
#     101
#    (...)    172     Name: 1, dtype: bool
#     173     """
# --> 174     return _isna(obj)
#
# RecursionError: maximum recursion depth exceeded
